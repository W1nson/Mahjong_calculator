# %%
import torch 


# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Images
imgs = ['MahJongTrainDataSet/temp.jpeg']  # batch of images

# Inference
results = model(imgs)

# Results
results.print()
results.show()  # or .show()

results.xyxy[0]  # img1 predictions (tensor)
results.pandas().xyxy[0]  # img1 predictions (pandas)
#      xmin    ymin    xmax   ymax  confidence  class    name
# 0  749.50   43.50  1148.0  704.5    0.874023      0  person
# 1  433.50  433.50   517.5  714.5    0.687988     27     tie
# 2  114.75  195.75  1095.0  708.0    0.624512      0  person
# 3  986.00  304.00  1028.0  420.0    0.286865     27     tie
# Out:
# Using cache found in /Users/winson/.cache/torch/hub/ultralytics_yolov5_master
# requirements: Ultralytics requirement ['setuptools>=65.5.1'] not found, attempting AutoUpdate...
# Requirement already satisfied: setuptools>=65.5.1 in /Users/winson/opt/anaconda3/envs/ML/lib/python3.8/site-packages (68.1.2)
#
# requirements: AutoUpdate success ✅ 3.0s, installed 1 package: ['setuptools>=65.5.1']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2023-8-20 Python-3.8.10 torch-2.0.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# image 1/1: 488x602 (no detections)
# Speed: 18.2ms pre-process, 438.8ms inference, 1.7ms NMS per image at shape (1, 3, 544, 640)
# <PIL.Image.Image image mode=RGB size=602x488 at 0x7FA0E67A9CD0>
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
