# %%
# imports 
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np 
import os 
import cv2

# %%
df = pd.read_csv('./data.csv')
df
# Out:
#     image-name  label    label-name
# 0        1.jpg     38  bonus-winter
# 1        2.jpg     26  characters-8
# 2        3.jpg      9        dots-9
# 3        4.jpg     36  bonus-summer
# 4        5.jpg     28   honors-east
# ..         ...    ...           ...
# 624    624.jpg     11      bamboo-2
# 625    625.jpg      2        dots-2
# 626    626.jpg     19  characters-1
# 627    627.jpg     10      bamboo-1
# 628    628.jpg      1        dots-1
#
# [629 rows x 3 columns]

# %%
path = './images'

imgs = df['image-name']
labels = df['label-name']


fig, axs = plt.subplots(4, 4, figsize=(16,16))
for i in range(16): 
    img = plt.imread(fname=os.path.join(path, imgs[i]))
    print(img.shape)
    axs[i//4, i%4].imshow(img)
    axs[i//4, i%4].set_title(labels[i])
 
plt.show()
# Out:
# (320, 240, 3)
# (320, 240, 3)
# (320, 240, 3)
# (320, 240, 3)
# (320, 240, 3)
# (320, 240, 3)
# (320, 240, 3)
# (320, 240, 3)
# (320, 240, 3)
# (320, 240, 3)
# (320, 240, 3)
# (320, 240, 3)
# (320, 240, 3)
# (320, 240, 3)
# (320, 240, 3)
# (320, 240, 3)

# %%
# using pd.unique to map all labels 
labels = [(label, name) for label, name in zip(df['label'],df['label-name'])]
unique_labels = pd.unique(labels)

print(unique_labels)

# using dictionary to map all labels
labels = {label: name for label, name in zip(df['label'],df['label-name'])}

print(labels)
# Out:
# [(38, 'bonus-winter') (26, 'characters-8') (9, 'dots-9')
#  (36, 'bonus-summer') (28, 'honors-east') (37, 'bonus-autumn')
#  (24, 'characters-6') (16, 'bamboo-7') (31, 'honors-north')
#  (30, 'honors-west') (20, 'characters-2') (23, 'characters-5')
#  (3, 'dots-3') (22, 'characters-4') (2, 'dots-2') (29, 'honors-south')
#  (25, 'characters-7') (7, 'dots-7') (6, 'dots-6') (33, 'honors-green')
#  (12, 'bamboo-3') (10, 'bamboo-1') (32, 'honors-red')
#  (41, 'bonus-chrysanthemum') (34, 'honors-white') (39, 'bonus-plum')
#  (27, 'characters-9') (19, 'characters-1') (21, 'characters-3')
#  (5, 'dots-5') (17, 'bamboo-8') (15, 'bamboo-6') (4, 'dots-4')
#  (11, 'bamboo-2') (13, 'bamboo-4') (8, 'dots-8') (18, 'bamboo-9')
#  (1, 'dots-1') (42, 'bonus-bamboo') (14, 'bamboo-5') (35, 'bonus-spring')
#  (40, 'bonus-orchid')]
# ...
